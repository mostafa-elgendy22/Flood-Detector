# %%
import gdown
gdown.download("https://drive.google.com/file/d/1YUbTBFrk9QF0ivR5F640G3dhCMC3XQUZ/view?usp=sharing", "dataset.zip", quiet=False, fuzzy=True)
gdown.extractall("dataset.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1YUbTBFrk9QF0ivR5F640G3dhCMC3XQUZ
# To: /content/dataset.zip
# 100%|██████████| 1.70G/1.70G [00:14<00:00, 116MB/s]
# ['dataset/',
#  'dataset/flooded/',
#  'dataset/flooded/0.jpg',
#  'dataset/flooded/1.jpg',
#  'dataset/flooded/10.jpg',
#  'dataset/flooded/100.jpg',
#  'dataset/flooded/101.jpg',
#  'dataset/flooded/102.jpg',
#  'dataset/flooded/103.jpg',
#  'dataset/flooded/104.jpg',
#  'dataset/flooded/105.jpg',
#  'dataset/flooded/106.jpg',
#  'dataset/flooded/107.jpg',
#  'dataset/flooded/108.jpg',
#  'dataset/flooded/109.jpg',
#  'dataset/flooded/11.jpg',
#  'dataset/flooded/110.jpg',
#  'dataset/flooded/111.jpg',
#  'dataset/flooded/112.jpg',
#  'dataset/flooded/113.jpg',
#  'dataset/flooded/114.jpg',
#  'dataset/flooded/115.jpg',
#  'dataset/flooded/116.jpg',
#  'dataset/flooded/117.jpg',
#  'dataset/flooded/118.jpg',
#  'dataset/flooded/119.jpg',
#  'dataset/flooded/12.jpg',
#  'dataset/flooded/120.jpg',
#  'dataset/flooded/121.jpg',
#  'dataset/flooded/122.jpg',
#  'dataset/flooded/123.jpg',
#  'dataset/flooded/124.jpg',
#  'dataset/flooded/125.jpg',
#  'dataset/flooded/126.jpg',
#  'dataset/flooded/127.jpg',
#  'dataset/flooded/128.jpg',
#  'dataset/flooded/129.jpg',
#  'dataset/flooded/13.jpg',
#  'dataset/flooded/130.jpg',
#  'dataset/flooded/131.jpg',
#  'dataset/flooded/132.jpg',
#  'dataset/flooded/133.jpg',
#  'dataset/flooded/134.jpg',
#  'dataset/flooded/135.jpg',
#  'dataset/flooded/136.jpg',
#  'dataset/flooded/137.jpg',
#  'dataset/flooded/138.jpg',
#  'dataset/flooded/139.jpg',
#  'dataset/flooded/14.jpg',
#  'dataset/flooded/140.jpg',
#  'dataset/flooded/141.jpg',
#  'dataset/flooded/142.jpg',
#  'dataset/flooded/143.jpg',
#  'dataset/flooded/144.jpg',
#  'dataset/flooded/145.jpg',
#  'dataset/flooded/146.jpg',
#  'dataset/flooded/147.jpg',
#  'dataset/flooded/148.jpg',
#  'dataset/flooded/149.jpg',
#  'dataset/flooded/15.jpg',
#  'dataset/flooded/150.jpg',
#  'dataset/flooded/151.jpg',
#  'dataset/flooded/152.jpg',
#  'dataset/flooded/153.jpg',
#  'dataset/flooded/154.jpg',
#  'dataset/flooded/155.jpg',
#  'dataset/flooded/156.jpg',
#  'dataset/flooded/157.jpg',
#  'dataset/flooded/158.jpg',
#  'dataset/flooded/159.jpg',
#  'dataset/flooded/16.jpg',
#  'dataset/flooded/160.jpg',
#  'dataset/flooded/161.jpg',
#  'dataset/flooded/162.jpg',
#  'dataset/flooded/163.jpg',
#  'dataset/flooded/164.jpg',
#  'dataset/flooded/165.jpg',
#  'dataset/flooded/166.jpg',
#  'dataset/flooded/167.jpg',
#  'dataset/flooded/168.jpg',
#  'dataset/flooded/169.jpg',
#  'dataset/flooded/17.jpg',
#  'dataset/flooded/170.jpg',
#  'dataset/flooded/171.jpg',
#  'dataset/flooded/172.jpg',
#  'dataset/flooded/173.jpg',
#  'dataset/flooded/174.jpg',
#  'dataset/flooded/175.jpg',
#  'dataset/flooded/176.jpg',
#  'dataset/flooded/177.jpg',
#  'dataset/flooded/178.jpg',
#  'dataset/flooded/179.jpg',
#  'dataset/flooded/18.jpg',
#  'dataset/flooded/180.jpg',
#  'dataset/flooded/181.jpg',
#  'dataset/flooded/182.jpg',
#  'dataset/flooded/183.jpg',
#  'dataset/flooded/184.jpg',
#  'dataset/flooded/185.jpg',
#  'dataset/flooded/186.jpg',
#  'dataset/flooded/187.jpg',
#  'dataset/flooded/188.jpg',
#  'dataset/flooded/189.jpg',
#  'dataset/flooded/19.jpg',
#  'dataset/flooded/190.jpg',
#  'dataset/flooded/191.jpg',
#  'dataset/flooded/192.jpg',
#  'dataset/flooded/193.jpg',
#  'dataset/flooded/194.jpg',
#  'dataset/flooded/195.jpg',
#  'dataset/flooded/196.jpg',
#  'dataset/flooded/197.jpg',
#  'dataset/flooded/198.jpg',
#  'dataset/flooded/199.jpg',
#  'dataset/flooded/2.jpg',
#  'dataset/flooded/20.jpg',
#  'dataset/flooded/200.jpg',
#  'dataset/flooded/201.jpg',
#  'dataset/flooded/202.jpg',
#  'dataset/flooded/203.jpg',
#  'dataset/flooded/204.jpg',
#  'dataset/flooded/205.jpg',
#  'dataset/flooded/206.jpg',
#  'dataset/flooded/207.jpg',
#  'dataset/flooded/208.jpg',
#  'dataset/flooded/209.jpg',
#  'dataset/flooded/21.jpg',
#  'dataset/flooded/210.jpg',
#  'dataset/flooded/211.jpg',
#  'dataset/flooded/212.jpg',
#  'dataset/flooded/213.jpg',
#  'dataset/flooded/214.jpg',
#  'dataset/flooded/215.jpg',
#  'dataset/flooded/216.jpg',
#  'dataset/flooded/217.jpg',
#  'dataset/flooded/218.jpg',
#  'dataset/flooded/219.jpg',
#  'dataset/flooded/22.jpg',
#  'dataset/flooded/220.jpg',
#  'dataset/flooded/221.jpg',
#  'dataset/flooded/222.jpg',
#  'dataset/flooded/223.jpg',
#  'dataset/flooded/224.jpg',
#  'dataset/flooded/225.jpg',
#  'dataset/flooded/226.jpg',
#  'dataset/flooded/227.jpg',
#  'dataset/flooded/228.jpg',
#  'dataset/flooded/229.jpg',
#  'dataset/flooded/23.jpg',
#  'dataset/flooded/230.jpg',
#  'dataset/flooded/231.jpg',
#  'dataset/flooded/232.jpg',
#  'dataset/flooded/233.jpg',
#  'dataset/flooded/234.jpg',
#  'dataset/flooded/235.jpg',
#  'dataset/flooded/236.jpg',
#  'dataset/flooded/237.jpg',
#  'dataset/flooded/238.jpg',
#  'dataset/flooded/239.jpg',
#  'dataset/flooded/24.jpg',
#  'dataset/flooded/240.jpg',
#  'dataset/flooded/241.jpg',
#  'dataset/flooded/242.jpg',
#  'dataset/flooded/243.jpg',
#  'dataset/flooded/244.jpg',
#  'dataset/flooded/245.jpg',
#  'dataset/flooded/246.jpg',
#  'dataset/flooded/247.jpg',
#  'dataset/flooded/248.jpg',
#  'dataset/flooded/249.jpg',
#  'dataset/flooded/25.jpg',
#  'dataset/flooded/250.jpg',
#  'dataset/flooded/251.jpg',
#  'dataset/flooded/252.jpg',
#  'dataset/flooded/253.jpg',
#  'dataset/flooded/254.jpg',
#  'dataset/flooded/255.jpg',
#  'dataset/flooded/256.jpg',
#  'dataset/flooded/257.jpg',
#  'dataset/flooded/258.jpg',
#  'dataset/flooded/259.jpg',
#  'dataset/flooded/26.jpg',
#  'dataset/flooded/260.jpg',
#  'dataset/flooded/261.jpg',
#  'dataset/flooded/262.jpg',
#  'dataset/flooded/263.jpg',
#  'dataset/flooded/264.jpg',
#  'dataset/flooded/265.jpg',
#  'dataset/flooded/266.jpg',
#  'dataset/flooded/267.jpg',
#  'dataset/flooded/268.jpg',
#  'dataset/flooded/269.jpg',
#  'dataset/flooded/27.jpg',
#  'dataset/flooded/270.jpg',
#  'dataset/flooded/271.jpg',
#  'dataset/flooded/272.jpg',
#  'dataset/flooded/273.jpg',
#  'dataset/flooded/274.jpg',
#  'dataset/flooded/275.jpg',
#  'dataset/flooded/276.jpg',
#  'dataset/flooded/277.jpg',
#  'dataset/flooded/278.jpg',
#  'dataset/flooded/279.jpg',
#  'dataset/flooded/28.jpg',
#  'dataset/flooded/280.jpg',
#  'dataset/flooded/281.jpg',
#  'dataset/flooded/282.jpg',
#  'dataset/flooded/283.jpg',
#  'dataset/flooded/284.jpg',
#  'dataset/flooded/285.jpg',
#  'dataset/flooded/286.jpg',
#  'dataset/flooded/287.jpg',
#  'dataset/flooded/288.jpg',
#  'dataset/flooded/289.jpg',
#  'dataset/flooded/29.jpg',
#  'dataset/flooded/290.jpg',
#  'dataset/flooded/291.jpg',
#  'dataset/flooded/292.jpg',
#  'dataset/flooded/293.jpg',
#  'dataset/flooded/294.jpg',
#  'dataset/flooded/295.jpg',
#  'dataset/flooded/296.jpg',
#  'dataset/flooded/297.jpg',
#  'dataset/flooded/298.jpg',
#  'dataset/flooded/299.jpg',
#  'dataset/flooded/3.jpg',
#  'dataset/flooded/30.jpg',
#  'dataset/flooded/300.jpg',
#  'dataset/flooded/301.jpg',
#  'dataset/flooded/302.jpg',
#  'dataset/flooded/303.jpg',
#  'dataset/flooded/304.jpg',
#  'dataset/flooded/305.jpg',
#  'dataset/flooded/306.jpg',
#  'dataset/flooded/307.jpg',
#  'dataset/flooded/308.jpg',
#  'dataset/flooded/309.jpg',
#  'dataset/flooded/31.jpg',
#  'dataset/flooded/310.jpg',
#  'dataset/flooded/311.jpg',
#  'dataset/flooded/312.jpg',
#  'dataset/flooded/313.jpg',
#  'dataset/flooded/314.jpg',
#  'dataset/flooded/315.jpg',
#  'dataset/flooded/316.jpg',
#  'dataset/flooded/317.jpg',
#  'dataset/flooded/318.jpg',
#  'dataset/flooded/319.jpg',
#  'dataset/flooded/32.jpg',
#  'dataset/flooded/320.jpg',
#  'dataset/flooded/321.jpg',
#  'dataset/flooded/322.jpg',
#  'dataset/flooded/323.jpg',
#  'dataset/flooded/324.jpg',
#  'dataset/flooded/325.jpg',
#  'dataset/flooded/326.jpg',
#  'dataset/flooded/327.jpg',
#  'dataset/flooded/328.jpg',
#  'dataset/flooded/329.jpg',
#  'dataset/flooded/33.jpg',
#  'dataset/flooded/330.jpg',
#  'dataset/flooded/331.jpg',
#  'dataset/flooded/332.jpg',
#  'dataset/flooded/333.jpg',
#  'dataset/flooded/334.jpg',
#  'dataset/flooded/335.jpg',
#  'dataset/flooded/336.jpg',
#  'dataset/flooded/337.jpg',
#  'dataset/flooded/338.jpg',
#  'dataset/flooded/339.jpg',
#  'dataset/flooded/34.jpg',
#  'dataset/flooded/340.jpg',
#  'dataset/flooded/341.jpg',
#  'dataset/flooded/342.jpg',
#  'dataset/flooded/343.jpg',
#  'dataset/flooded/344.jpg',
#  'dataset/flooded/345.jpg',
#  'dataset/flooded/346.jpg',
#  'dataset/flooded/347.jpg',
#  'dataset/flooded/348.jpg',
#  'dataset/flooded/349.jpg',
#  'dataset/flooded/35.jpg',
#  'dataset/flooded/350.jpg',
#  'dataset/flooded/351.jpg',
#  'dataset/flooded/352.jpg',
#  'dataset/flooded/353.jpg',
#  'dataset/flooded/354.jpg',
#  'dataset/flooded/355.jpg',
#  'dataset/flooded/356.jpg',
#  'dataset/flooded/357.jpg',
#  'dataset/flooded/358.jpg',
#  'dataset/flooded/359.jpg',
#  'dataset/flooded/36.jpg',
#  'dataset/flooded/360.jpg',
#  'dataset/flooded/361.jpg',
#  'dataset/flooded/362.jpg',
#  'dataset/flooded/363.jpg',
#  'dataset/flooded/364.jpg',
#  'dataset/flooded/365.jpg',
#  'dataset/flooded/366.jpg',
#  'dataset/flooded/367.jpg',
#  'dataset/flooded/368.jpg',
#  'dataset/flooded/369.jpg',
#  'dataset/flooded/37.jpg',
#  'dataset/flooded/370.jpg',
#  'dataset/flooded/371.jpg',
#  'dataset/flooded/372.jpg',
#  'dataset/flooded/373.jpg',
#  'dataset/flooded/374.jpg',
#  'dataset/flooded/375.jpg',
#  'dataset/flooded/376.jpg',
#  'dataset/flooded/377.jpg',
#  'dataset/flooded/378.jpg',
#  'dataset/flooded/379.jpg',
#  'dataset/flooded/38.jpg',
#  'dataset/flooded/380.jpg',
#  'dataset/flooded/381.jpg',
#  'dataset/flooded/382.jpg',
#  'dataset/flooded/383.jpg',
#  'dataset/flooded/384.jpg',
#  'dataset/flooded/385.jpg',
#  'dataset/flooded/386.jpg',
#  'dataset/flooded/387.jpg',
#  'dataset/flooded/388.jpg',
#  'dataset/flooded/389.jpg',
#  'dataset/flooded/39.jpg',
#  'dataset/flooded/390.jpg',
#  'dataset/flooded/391.jpg',
#  'dataset/flooded/392.jpg',
#  'dataset/flooded/393.jpg',
#  'dataset/flooded/394.jpg',
#  'dataset/flooded/395.jpg',
#  'dataset/flooded/396.jpg',
#  'dataset/flooded/397.jpg',
#  'dataset/flooded/398.jpg',
#  'dataset/flooded/399.jpg',
#  'dataset/flooded/4.jpg',
#  'dataset/flooded/40.jpg',
#  'dataset/flooded/400.jpg',
#  'dataset/flooded/401.jpg',
#  'dataset/flooded/402.jpg',
#  'dataset/flooded/403.jpg',
#  'dataset/flooded/404.jpg',
#  'dataset/flooded/405.jpg',
#  'dataset/flooded/406.jpg',
#  'dataset/flooded/407.jpg',
#  'dataset/flooded/408.jpg',
#  'dataset/flooded/409.jpg',
#  'dataset/flooded/41.jpg',
#  'dataset/flooded/410.jpg',
#  'dataset/flooded/411.jpg',
#  'dataset/flooded/412.jpg',
#  'dataset/flooded/413.jpg',
#  'dataset/flooded/414.jpg',
#  'dataset/flooded/415.jpg',
#  'dataset/flooded/416.jpg',
#  'dataset/flooded/417.jpg',
#  'dataset/flooded/418.jpg',
#  'dataset/flooded/419.jpg',
#  'dataset/flooded/42.jpg',
#  'dataset/flooded/420.jpg',
#  'dataset/flooded/421.jpg',
#  'dataset/flooded/422.jpg',
#  'dataset/flooded/423.jpg',
#  'dataset/flooded/424.jpg',
#  'dataset/flooded/425.jpg',
#  'dataset/flooded/426.jpg',
#  'dataset/flooded/427.jpg',
#  'dataset/flooded/428.jpg',
#  'dataset/flooded/429.jpg',
#  'dataset/flooded/43.jpg',
#  'dataset/flooded/430.jpg',
#  'dataset/flooded/431.jpg',
#  'dataset/flooded/432.jpg',
#  'dataset/flooded/433.jpg',
#  'dataset/flooded/434.jpg',
#  'dataset/flooded/435.jpg',
#  'dataset/flooded/436.jpg',
#  'dataset/flooded/437.jpg',
#  'dataset/flooded/438.jpg',
#  'dataset/flooded/439.jpg',
#  'dataset/flooded/44.jpg',
#  'dataset/flooded/440.jpg',
#  'dataset/flooded/441.jpg',
#  'dataset/flooded/442.jpg',
#  'dataset/flooded/443.jpg',
#  'dataset/flooded/444.jpg',
#  'dataset/flooded/445.jpg',
#  'dataset/flooded/446.jpg',
#  'dataset/flooded/447.jpg',
#  'dataset/flooded/448.jpg',
#  'dataset/flooded/449.jpg',
#  'dataset/flooded/45.jpg',
#  'dataset/flooded/450.jpg',
#  'dataset/flooded/451.jpg',
#  'dataset/flooded/452.jpg',
#  'dataset/flooded/453.jpg',
#  'dataset/flooded/454.jpg',
#  'dataset/flooded/455.jpg',
#  'dataset/flooded/456.jpg',
#  'dataset/flooded/457.jpg',
#  'dataset/flooded/458.jpg',
#  'dataset/flooded/459.jpg',
#  'dataset/flooded/46.jpg',
#  'dataset/flooded/460.jpg',
#  'dataset/flooded/47.jpg',
#  'dataset/flooded/48.jpg',
#  'dataset/flooded/49.jpg',
#  'dataset/flooded/5.jpg',
#  'dataset/flooded/50.jpg',
#  'dataset/flooded/51.jpg',
#  'dataset/flooded/52.jpg',
#  'dataset/flooded/53.jpg',
#  'dataset/flooded/54.jpg',
#  'dataset/flooded/55.jpg',
#  'dataset/flooded/56.jpg',
#  'dataset/flooded/57.jpg',
#  'dataset/flooded/58.jpg',
#  'dataset/flooded/59.jpg',
#  'dataset/flooded/6.jpg',
#  'dataset/flooded/60.jpg',
#  'dataset/flooded/61.jpg',
#  'dataset/flooded/62.jpg',
#  'dataset/flooded/63.jpg',
#  'dataset/flooded/64.jpg',
#  'dataset/flooded/65.jpg',
#  'dataset/flooded/66.jpg',
#  'dataset/flooded/67.jpg',
#  'dataset/flooded/68.jpg',
#  'dataset/flooded/69.jpg',
#  'dataset/flooded/7.jpg',
#  'dataset/flooded/70.jpg',
#  'dataset/flooded/71.jpg',
#  'dataset/flooded/72.jpg',
#  'dataset/flooded/73.jpg',
#  'dataset/flooded/74.jpg',
#  'dataset/flooded/75.jpg',
#  'dataset/flooded/76.jpg',
#  'dataset/flooded/77.jpg',
#  'dataset/flooded/78.jpg',
#  'dataset/flooded/79.jpg',
#  'dataset/flooded/8.jpg',
#  'dataset/flooded/80.jpg',
#  'dataset/flooded/81.jpg',
#  'dataset/flooded/82.jpg',
#  'dataset/flooded/83.jpg',
#  'dataset/flooded/84.jpg',
#  'dataset/flooded/85.jpg',
#  'dataset/flooded/86.jpg',
#  'dataset/flooded/87.jpg',
#  'dataset/flooded/88.jpg',
#  'dataset/flooded/89.jpg',
#  'dataset/flooded/9.jpg',
#  'dataset/flooded/90.jpg',
#  'dataset/flooded/91.jpg',
#  'dataset/flooded/92.jpg',
#  'dataset/flooded/93.jpg',
#  'dataset/flooded/94.jpg',
#  'dataset/flooded/95.jpg',
#  'dataset/flooded/96.jpg',
#  'dataset/flooded/97.jpg',
#  'dataset/flooded/98.jpg',
#  'dataset/flooded/99.jpg',
#  'dataset/non-flooded/',
#  'dataset/non-flooded/1000.jpg',
#  'dataset/non-flooded/1001.jpg',
#  'dataset/non-flooded/1002.jpg',
#  'dataset/non-flooded/1003.jpg',
#  'dataset/non-flooded/1004.jpg',
#  'dataset/non-flooded/1005.jpg',
#  'dataset/non-flooded/1006.jpg',
#  'dataset/non-flooded/1007.jpg',
#  'dataset/non-flooded/1008.jpg',
#  'dataset/non-flooded/1009.jpg',
#  'dataset/non-flooded/1010.jpg',
#  'dataset/non-flooded/1011.jpg',
#  'dataset/non-flooded/1012.jpg',
#  'dataset/non-flooded/1013.jpg',
#  'dataset/non-flooded/1014.jpg',
#  'dataset/non-flooded/1015.jpg',
#  'dataset/non-flooded/1016.jpg',
#  'dataset/non-flooded/1017.jpg',
#  'dataset/non-flooded/1018.jpg',
#  'dataset/non-flooded/1019.jpg',
#  'dataset/non-flooded/1020.jpg',
#  'dataset/non-flooded/1021.jpg',
#  'dataset/non-flooded/1022.jpg',
#  'dataset/non-flooded/1023.jpg',
#  'dataset/non-flooded/1024.jpg',
#  'dataset/non-flooded/1025.jpg',
#  'dataset/non-flooded/1026.jpg',
#  'dataset/non-flooded/1027.jpg',
#  'dataset/non-flooded/1028.jpg',
#  'dataset/non-flooded/1029.jpg',
#  'dataset/non-flooded/1030.jpg',
#  'dataset/non-flooded/1031.jpg',
#  'dataset/non-flooded/1032.jpg',
#  'dataset/non-flooded/1033.jpg',
#  'dataset/non-flooded/1034.jpg',
#  'dataset/non-flooded/1035.jpg',
#  'dataset/non-flooded/1036.jpg',
#  'dataset/non-flooded/1037.jpg',
#  'dataset/non-flooded/1038.jpg',
#  'dataset/non-flooded/578.jpg',
#  'dataset/non-flooded/579.jpg',
#  'dataset/non-flooded/580.jpg',
#  'dataset/non-flooded/581.jpg',
#  'dataset/non-flooded/582.jpg',
#  'dataset/non-flooded/583.jpg',
#  'dataset/non-flooded/584.jpg',
#  'dataset/non-flooded/585.jpg',
#  'dataset/non-flooded/586.jpg',
#  'dataset/non-flooded/587.jpg',
#  'dataset/non-flooded/588.jpg',
#  'dataset/non-flooded/589.jpg',
#  'dataset/non-flooded/590.jpg',
#  'dataset/non-flooded/591.jpg',
#  'dataset/non-flooded/592.jpg',
#  'dataset/non-flooded/593.jpg',
#  'dataset/non-flooded/594.jpg',
#  'dataset/non-flooded/595.jpg',
#  'dataset/non-flooded/596.jpg',
#  'dataset/non-flooded/597.jpg',
#  'dataset/non-flooded/598.jpg',
#  'dataset/non-flooded/599.jpg',
#  'dataset/non-flooded/600.jpg',
#  'dataset/non-flooded/601.jpg',
#  'dataset/non-flooded/602.jpg',
#  'dataset/non-flooded/603.jpg',
#  'dataset/non-flooded/604.jpg',
#  'dataset/non-flooded/605.jpg',
#  'dataset/non-flooded/606.jpg',
#  'dataset/non-flooded/607.jpg',
#  'dataset/non-flooded/608.jpg',
#  'dataset/non-flooded/609.jpg',
#  'dataset/non-flooded/610.jpg',
#  'dataset/non-flooded/611.jpg',
#  'dataset/non-flooded/612.jpg',
#  'dataset/non-flooded/613.jpg',
#  'dataset/non-flooded/614.jpg',
#  'dataset/non-flooded/615.jpg',
#  'dataset/non-flooded/616.jpg',
#  'dataset/non-flooded/617.jpg',
#  'dataset/non-flooded/618.jpg',
#  'dataset/non-flooded/619.jpg',
#  'dataset/non-flooded/620.jpg',
#  'dataset/non-flooded/621.jpg',
#  'dataset/non-flooded/622.jpg',
#  'dataset/non-flooded/623.jpg',
#  'dataset/non-flooded/624.jpg',
#  'dataset/non-flooded/625.jpg',
#  'dataset/non-flooded/626.jpg',
#  'dataset/non-flooded/627.jpg',
#  'dataset/non-flooded/628.jpg',
#  'dataset/non-flooded/629.jpg',
#  'dataset/non-flooded/630.jpg',
#  'dataset/non-flooded/631.jpg',
#  'dataset/non-flooded/632.jpg',
#  'dataset/non-flooded/633.jpg',
#  'dataset/non-flooded/634.jpg',
#  'dataset/non-flooded/635.jpg',
#  'dataset/non-flooded/636.jpg',
#  'dataset/non-flooded/637.jpg',
#  'dataset/non-flooded/638.jpg',
#  'dataset/non-flooded/639.jpg',
#  'dataset/non-flooded/640.jpg',
#  'dataset/non-flooded/641.jpg',
#  'dataset/non-flooded/642.jpg',
#  'dataset/non-flooded/643.jpg',
#  'dataset/non-flooded/644.jpg',
#  'dataset/non-flooded/645.jpg',
#  'dataset/non-flooded/646.jpg',
#  'dataset/non-flooded/647.jpg',
#  'dataset/non-flooded/648.jpg',
#  'dataset/non-flooded/649.jpg',
#  'dataset/non-flooded/650.jpg',
#  'dataset/non-flooded/651.jpg',
#  'dataset/non-flooded/652.jpg',
#  'dataset/non-flooded/653.jpg',
#  'dataset/non-flooded/654.jpg',
#  'dataset/non-flooded/655.jpg',
#  'dataset/non-flooded/656.jpg',
#  'dataset/non-flooded/657.jpg',
#  'dataset/non-flooded/658.jpg',
#  'dataset/non-flooded/659.jpg',
#  'dataset/non-flooded/660.jpg',
#  'dataset/non-flooded/661.jpg',
#  'dataset/non-flooded/662.jpg',
#  'dataset/non-flooded/663.jpg',
#  'dataset/non-flooded/664.jpg',
#  'dataset/non-flooded/665.jpg',
#  'dataset/non-flooded/666.jpg',
#  'dataset/non-flooded/667.jpg',
#  'dataset/non-flooded/668.jpg',
#  'dataset/non-flooded/669.jpg',
#  'dataset/non-flooded/670.jpg',
#  'dataset/non-flooded/671.jpg',
#  'dataset/non-flooded/672.jpg',
#  'dataset/non-flooded/673.jpg',
#  'dataset/non-flooded/674.jpg',
#  'dataset/non-flooded/675.jpg',
#  'dataset/non-flooded/676.jpg',
#  'dataset/non-flooded/677.jpg',
#  'dataset/non-flooded/678.jpg',
#  'dataset/non-flooded/679.jpg',
#  'dataset/non-flooded/680.jpg',
#  'dataset/non-flooded/681.jpg',
#  'dataset/non-flooded/682.jpg',
#  'dataset/non-flooded/683.jpg',
#  'dataset/non-flooded/684.jpg',
#  'dataset/non-flooded/685.jpg',
#  'dataset/non-flooded/686.jpg',
#  'dataset/non-flooded/687.jpg',
#  'dataset/non-flooded/688.jpg',
#  'dataset/non-flooded/689.jpg',
#  'dataset/non-flooded/690.jpg',
#  'dataset/non-flooded/691.jpg',
#  'dataset/non-flooded/692.jpg',
#  'dataset/non-flooded/693.jpg',
#  'dataset/non-flooded/694.jpg',
#  'dataset/non-flooded/695.jpg',
#  'dataset/non-flooded/696.jpg',
#  'dataset/non-flooded/697.jpg',
#  'dataset/non-flooded/698.jpg',
#  'dataset/non-flooded/699.jpg',
#  'dataset/non-flooded/700.jpg',
#  'dataset/non-flooded/701.jpg',
#  'dataset/non-flooded/702.jpg',
#  'dataset/non-flooded/703.jpg',
#  'dataset/non-flooded/704.jpg',
#  'dataset/non-flooded/705.jpg',
#  'dataset/non-flooded/706.jpg',
#  'dataset/non-flooded/707.jpg',
#  'dataset/non-flooded/708.jpg',
#  'dataset/non-flooded/709.jpg',
#  'dataset/non-flooded/710.jpg',
#  'dataset/non-flooded/711.jpg',
#  'dataset/non-flooded/712.jpg',
#  'dataset/non-flooded/713.jpg',
#  'dataset/non-flooded/714.jpg',
#  'dataset/non-flooded/715.jpg',
#  'dataset/non-flooded/716.jpg',
#  'dataset/non-flooded/717.jpg',
#  'dataset/non-flooded/718.jpg',
#  'dataset/non-flooded/719.jpg',
#  'dataset/non-flooded/720.jpg',
#  'dataset/non-flooded/721.jpg',
#  'dataset/non-flooded/722.jpg',
#  'dataset/non-flooded/723.jpg',
#  'dataset/non-flooded/724.jpg',
#  'dataset/non-flooded/725.jpg',
#  'dataset/non-flooded/726.jpg',
#  'dataset/non-flooded/727.jpg',
#  'dataset/non-flooded/728.jpg',
#  'dataset/non-flooded/729.jpg',
#  'dataset/non-flooded/730.jpg',
#  'dataset/non-flooded/731.jpg',
#  'dataset/non-flooded/732.jpg',
#  'dataset/non-flooded/733.jpg',
#  'dataset/non-flooded/734.jpg',
#  'dataset/non-flooded/735.jpg',
#  'dataset/non-flooded/736.jpg',
#  'dataset/non-flooded/737.jpg',
#  'dataset/non-flooded/738.jpg',
#  'dataset/non-flooded/739.jpg',
#  'dataset/non-flooded/740.jpg',
#  'dataset/non-flooded/741.jpg',
#  'dataset/non-flooded/742.jpg',
#  'dataset/non-flooded/743.jpg',
#  'dataset/non-flooded/744.jpg',
#  'dataset/non-flooded/745.jpg',
#  'dataset/non-flooded/746.jpg',
#  'dataset/non-flooded/747.jpg',
#  'dataset/non-flooded/748.jpg',
#  'dataset/non-flooded/749.jpg',
#  'dataset/non-flooded/750.jpg',
#  'dataset/non-flooded/751.jpg',
#  'dataset/non-flooded/752.jpg',
#  'dataset/non-flooded/753.jpg',
#  'dataset/non-flooded/754.jpg',
#  'dataset/non-flooded/755.jpg',
#  'dataset/non-flooded/756.jpg',
#  'dataset/non-flooded/757.jpg',
#  'dataset/non-flooded/758.jpg',
#  'dataset/non-flooded/759.jpg',
#  'dataset/non-flooded/760.jpg',
#  'dataset/non-flooded/761.jpg',
#  'dataset/non-flooded/762.jpg',
#  'dataset/non-flooded/763.jpg',
#  'dataset/non-flooded/764.jpg',
#  'dataset/non-flooded/765.jpg',
#  'dataset/non-flooded/766.jpg',
#  'dataset/non-flooded/767.jpg',
#  'dataset/non-flooded/768.jpg',
#  'dataset/non-flooded/769.jpg',
#  'dataset/non-flooded/770.jpg',
#  'dataset/non-flooded/771.jpg',
#  'dataset/non-flooded/772.jpg',
#  'dataset/non-flooded/773.jpg',
#  'dataset/non-flooded/774.jpg',
#  'dataset/non-flooded/775.jpg',
#  'dataset/non-flooded/776.jpg',
#  'dataset/non-flooded/777.jpg',
#  'dataset/non-flooded/778.jpg',
#  'dataset/non-flooded/779.jpg',
#  'dataset/non-flooded/780.jpg',
#  'dataset/non-flooded/781.jpg',
#  'dataset/non-flooded/782.jpg',
#  'dataset/non-flooded/783.jpg',
#  'dataset/non-flooded/784.jpg',
#  'dataset/non-flooded/785.jpg',
#  'dataset/non-flooded/786.jpg',
#  'dataset/non-flooded/787.jpg',
#  'dataset/non-flooded/788.jpg',
#  'dataset/non-flooded/789.jpg',
#  'dataset/non-flooded/790.jpg',
#  'dataset/non-flooded/791.jpg',
#  'dataset/non-flooded/792.jpg',
#  'dataset/non-flooded/793.jpg',
#  'dataset/non-flooded/794.jpg',
#  'dataset/non-flooded/795.jpg',
#  'dataset/non-flooded/796.jpg',
#  'dataset/non-flooded/797.jpg',
#  'dataset/non-flooded/798.jpg',
#  'dataset/non-flooded/799.jpg',
#  'dataset/non-flooded/800.jpg',
#  'dataset/non-flooded/801.jpg',
#  'dataset/non-flooded/802.jpg',
#  'dataset/non-flooded/803.jpg',
#  'dataset/non-flooded/804.jpg',
#  'dataset/non-flooded/805.jpg',
#  'dataset/non-flooded/806.jpg',
#  'dataset/non-flooded/807.jpg',
#  'dataset/non-flooded/808.jpg',
#  'dataset/non-flooded/809.jpg',
#  'dataset/non-flooded/810.jpg',
#  'dataset/non-flooded/811.jpg',
#  'dataset/non-flooded/812.jpg',
#  'dataset/non-flooded/813.jpg',
#  'dataset/non-flooded/814.jpg',
#  'dataset/non-flooded/815.jpg',
#  'dataset/non-flooded/816.jpg',
#  'dataset/non-flooded/817.jpg',
#  'dataset/non-flooded/818.jpg',
#  'dataset/non-flooded/819.jpg',
#  'dataset/non-flooded/820.jpg',
#  'dataset/non-flooded/821.jpg',
#  'dataset/non-flooded/822.jpg',
#  'dataset/non-flooded/823.jpg',
#  'dataset/non-flooded/824.jpg',
#  'dataset/non-flooded/825.jpg',
#  'dataset/non-flooded/826.jpg',
#  'dataset/non-flooded/827.jpg',
#  'dataset/non-flooded/828.jpg',
#  'dataset/non-flooded/829.jpg',
#  'dataset/non-flooded/830.jpg',
#  'dataset/non-flooded/831.jpg',
#  'dataset/non-flooded/832.jpg',
#  'dataset/non-flooded/833.jpg',
#  'dataset/non-flooded/834.jpg',
#  'dataset/non-flooded/835.jpg',
#  'dataset/non-flooded/836.jpg',
#  'dataset/non-flooded/837.jpg',
#  'dataset/non-flooded/838.jpg',
#  'dataset/non-flooded/839.jpg',
#  'dataset/non-flooded/840.jpg',
#  'dataset/non-flooded/841.jpg',
#  'dataset/non-flooded/842.jpg',
#  'dataset/non-flooded/843.jpg',
#  'dataset/non-flooded/844.jpg',
#  'dataset/non-flooded/845.jpg',
#  'dataset/non-flooded/846.jpg',
#  'dataset/non-flooded/847.jpg',
#  'dataset/non-flooded/848.jpg',
#  'dataset/non-flooded/849.jpg',
#  'dataset/non-flooded/850.jpg',
#  'dataset/non-flooded/851.jpg',
#  'dataset/non-flooded/852.jpg',
#  'dataset/non-flooded/853.jpg',
#  'dataset/non-flooded/854.jpg',
#  'dataset/non-flooded/855.jpg',
#  'dataset/non-flooded/856.jpg',
#  'dataset/non-flooded/857.jpg',
#  'dataset/non-flooded/858.jpg',
#  'dataset/non-flooded/859.jpg',
#  'dataset/non-flooded/860.jpg',
#  'dataset/non-flooded/861.jpg',
#  'dataset/non-flooded/862.jpg',
#  'dataset/non-flooded/863.jpg',
#  'dataset/non-flooded/864.jpg',
#  'dataset/non-flooded/865.jpg',
#  'dataset/non-flooded/866.jpg',
#  'dataset/non-flooded/867.jpg',
#  'dataset/non-flooded/868.jpg',
#  'dataset/non-flooded/869.jpg',
#  'dataset/non-flooded/870.jpg',
#  'dataset/non-flooded/871.jpg',
#  'dataset/non-flooded/872.jpg',
#  'dataset/non-flooded/873.jpg',
#  'dataset/non-flooded/874.jpg',
#  'dataset/non-flooded/875.jpg',
#  'dataset/non-flooded/876.jpg',
#  'dataset/non-flooded/877.jpg',
#  'dataset/non-flooded/878.jpg',
#  'dataset/non-flooded/879.jpg',
#  'dataset/non-flooded/880.jpg',
#  'dataset/non-flooded/881.jpg',
#  'dataset/non-flooded/882.jpg',
#  'dataset/non-flooded/883.jpg',
#  'dataset/non-flooded/884.jpg',
#  'dataset/non-flooded/885.jpg',
#  'dataset/non-flooded/886.jpg',
#  'dataset/non-flooded/887.jpg',
#  'dataset/non-flooded/888.jpg',
#  'dataset/non-flooded/889.jpg',
#  'dataset/non-flooded/890.jpg',
#  'dataset/non-flooded/891.jpg',
#  'dataset/non-flooded/892.jpg',
#  'dataset/non-flooded/893.jpg',
#  'dataset/non-flooded/894.jpg',
#  'dataset/non-flooded/895.jpg',
#  'dataset/non-flooded/896.jpg',
#  'dataset/non-flooded/897.jpg',
#  'dataset/non-flooded/898.jpg',
#  'dataset/non-flooded/899.jpg',
#  'dataset/non-flooded/900.jpg',
#  'dataset/non-flooded/901.jpg',
#  'dataset/non-flooded/902.jpg',
#  'dataset/non-flooded/903.jpg',
#  'dataset/non-flooded/904.jpg',
#  'dataset/non-flooded/905.jpg',
#  'dataset/non-flooded/906.jpg',
#  'dataset/non-flooded/907.jpg',
#  'dataset/non-flooded/908.jpg',
#  'dataset/non-flooded/909.jpg',
#  'dataset/non-flooded/910.jpg',
#  'dataset/non-flooded/911.jpg',
#  'dataset/non-flooded/912.jpg',
#  'dataset/non-flooded/913.jpg',
#  'dataset/non-flooded/914.jpg',
#  'dataset/non-flooded/915.jpg',
#  'dataset/non-flooded/916.jpg',
#  'dataset/non-flooded/917.jpg',
#  'dataset/non-flooded/918.jpg',
#  'dataset/non-flooded/919.jpg',
#  'dataset/non-flooded/920.jpg',
#  'dataset/non-flooded/921.jpg',
#  'dataset/non-flooded/922.jpg',
#  'dataset/non-flooded/923.jpg',
#  'dataset/non-flooded/924.jpg',
#  'dataset/non-flooded/925.jpg',
#  'dataset/non-flooded/926.jpg',
#  'dataset/non-flooded/927.jpg',
#  'dataset/non-flooded/928.jpg',
#  'dataset/non-flooded/929.jpg',
#  'dataset/non-flooded/930.jpg',
#  'dataset/non-flooded/931.jpg',
#  'dataset/non-flooded/932.jpg',
#  'dataset/non-flooded/933.jpg',
#  'dataset/non-flooded/934.jpg',
#  'dataset/non-flooded/935.jpg',
#  'dataset/non-flooded/936.jpg',
#  'dataset/non-flooded/937.jpg',
#  'dataset/non-flooded/938.jpg',
#  'dataset/non-flooded/939.jpg',
#  'dataset/non-flooded/940.jpg',
#  'dataset/non-flooded/941.jpg',
#  'dataset/non-flooded/942.jpg',
#  'dataset/non-flooded/943.jpg',
#  'dataset/non-flooded/944.jpg',
#  'dataset/non-flooded/945.jpg',
#  'dataset/non-flooded/946.jpg',
#  'dataset/non-flooded/947.jpg',
#  'dataset/non-flooded/948.jpg',
#  'dataset/non-flooded/949.jpg',
#  'dataset/non-flooded/950.jpg',
#  'dataset/non-flooded/951.jpg',
#  'dataset/non-flooded/952.jpg',
#  'dataset/non-flooded/953.jpg',
#  'dataset/non-flooded/954.jpg',
#  'dataset/non-flooded/955.jpg',
#  'dataset/non-flooded/956.jpg',
#  'dataset/non-flooded/957.jpg',
#  'dataset/non-flooded/958.jpg',
#  'dataset/non-flooded/959.jpg',
#  'dataset/non-flooded/960.jpg',
#  'dataset/non-flooded/961.jpg',
#  'dataset/non-flooded/962.jpg',
#  'dataset/non-flooded/963.jpg',
#  'dataset/non-flooded/964.jpg',
#  'dataset/non-flooded/965.jpg',
#  'dataset/non-flooded/966.jpg',
#  'dataset/non-flooded/967.jpg',
#  'dataset/non-flooded/968.jpg',
#  'dataset/non-flooded/969.jpg',
#  'dataset/non-flooded/970.jpg',
#  'dataset/non-flooded/971.jpg',
#  'dataset/non-flooded/972.jpg',
#  'dataset/non-flooded/973.jpg',
#  'dataset/non-flooded/974.jpg',
#  'dataset/non-flooded/975.jpg',
#  'dataset/non-flooded/976.jpg',
#  'dataset/non-flooded/977.jpg',
#  'dataset/non-flooded/978.jpg',
#  'dataset/non-flooded/979.jpg',
#  'dataset/non-flooded/980.jpg',
#  'dataset/non-flooded/981.jpg',
#  'dataset/non-flooded/982.jpg',
#  'dataset/non-flooded/983.jpg',
#  'dataset/non-flooded/984.jpg',
#  'dataset/non-flooded/985.jpg',
#  'dataset/non-flooded/986.jpg',
#  'dataset/non-flooded/987.jpg',
#  'dataset/non-flooded/988.jpg',
#  'dataset/non-flooded/989.jpg',
#  'dataset/non-flooded/990.jpg',
#  'dataset/non-flooded/991.jpg',
#  'dataset/non-flooded/992.jpg',
#  'dataset/non-flooded/993.jpg',
#  'dataset/non-flooded/994.jpg',
#  'dataset/non-flooded/995.jpg',
#  'dataset/non-flooded/996.jpg',
#  'dataset/non-flooded/997.jpg',
#  'dataset/non-flooded/998.jpg',
#  'dataset/non-flooded/999.jpg']

# %%
import pandas as pd
import numpy as np
import glob
import os
import cv2
from skimage.feature import hog, graycomatrix, graycoprops
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC as SVMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import classification_report

# %%
df = pd.DataFrame(columns=['image_path', 'label'])

for image_path in sorted(glob.glob('dataset/flooded/*.jpg')):
    data = {'image_path': image_path, 'label': 1}
    df.loc[len(df)] = data

for image_path in sorted(glob.glob('dataset/non-flooded/*.jpg')):
    data = {'image_path': image_path, 'label': 0}
    df.loc[len(df)] = data

# %%
def preprocess(image):
  resized_image = cv2.resize(image, (1352, 1794))
  edge_enhancement_filter = np.asarray([[0, 1, 0], [-1, 6.5, -1], [0, 1, 0]])
  preprocessed_image = cv2.filter2D(src=resized_image, ddepth=-1, kernel=edge_enhancement_filter)
  
  return preprocessed_image

# %%
def extract_features(image_path):
  RGB_image = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)
  preprocessed_image = preprocess(RGB_image)

  hog_feature = hog(preprocessed_image, pixels_per_cell=(128, 128), transform_sqrt=True,
                    cells_per_block=(2, 2), channel_axis=-1)
  
  gray_image = cv2.cvtColor(preprocessed_image, cv2.COLOR_RGB2GRAY)
  # Calculate the GLCM
  distances = [1]
  angles = [0, np.pi/4, np.pi/2, 3*np.pi/4]
  glcm = graycomatrix(gray_image, distances, angles, levels=256, symmetric=True, normed=True)

  # Calculate GLCM properties
  contrast = graycoprops(glcm, 'contrast')
  dissimilarity = graycoprops(glcm, 'dissimilarity')
  energy = graycoprops(glcm, 'energy')
  correlation = graycoprops(glcm, 'correlation')
  # print(len(contrast.ravel()) + len(dissimilarity.ravel()) + len(energy.ravel()) + len(correlation.ravel()))
  

  feature_vector = np.concatenate((hog_feature, contrast.ravel(), dissimilarity.ravel(), energy.ravel(), correlation.ravel()))
  return feature_vector

# %%
X = np.empty((len(df), 4212 + 16))
y = np.empty((len(df)))
for i, row in df.iterrows():
  features = extract_features(row['image_path'])
  X[i] = features
  y[i] = row['label']

# %%
print(f'The shape of the dataset is {X.shape}')
print(f'The total number of features in each image is {X.shape[1]}')
# Out:
# The shape of the dataset is (922, 4228)
# The total number of features in each image is 4228

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.2, random_state = 42)

# %%
param_grid = {
    'n_estimators': [25, 30, 50, 100],
    'max_depth': [None, 3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
grid.fit(X_train, y_train)

# print the best parameters found
print("Best parameters: ", grid.best_params_)

rf_classifier = grid.best_estimator_
# Out:
# Best parameters:  {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}

# %%
xgb_classifier = XGBClassifier(n_estimators=90)
svm_classifier = SVMClassifier(kernel='poly', degree=3, probability=True)
rf_classifier = RandomForestClassifier(max_depth=5, max_features='sqrt', min_samples_leaf=2, min_samples_split=5, n_estimators=100)

model = VotingClassifier(
    estimators=[('xgb', xgb_classifier), ('rf', rf_classifier),
                ('svm', svm_classifier)],
    voting='soft'
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.78      0.82        93
#          1.0       0.80      0.87      0.83        92
#
#     accuracy                           0.83       185
#    macro avg       0.83      0.83      0.83       185
# weighted avg       0.83      0.83      0.83       185

# %%
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
